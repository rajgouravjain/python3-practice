# %%
from matplotlib import pyplot as plt
plt.figure()
plt.subplot(121)
plt.plot([1,23,4,6,7])
plt.show()

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt
plt.figure()
plt.subplot(121)
plt.plot([1,23,4,6,7])
plt.show()
